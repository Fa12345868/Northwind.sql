# %%
# %load_ext sql

# %%
# %sql sqlite:///Northwind.db

# %%
# !pip install pandas sqlalchemy mysql-connector-python

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:20056@localhost/Northwind

# %%
# %%sql
# SELECT
# *
# FROM
#     Employee ;
# Out:
#  * mysql+pymysql://root:***@localhost/Northwind
#    sqlite:///Northwind.db
# 2 rows affected.
# [(2, 'Doe', 'Jane', 'Sales Rep', 'Mr.', datetime.datetime(1976, 6, 17, 0, 0), datetime.datetime(2012, 9, 22, 0, 0), '661 Main St', 'Houston', 'Region 2', '34658', 'Canada', '451-5059', '992', 'No notes', 5, 'photos/jane.jpg', 10685.2),
#  (3, 'Johnson', 'Alice', 'Support', 'Ms.', datetime.datetime(1973, 11, 10, 0, 0), datetime.datetime(2005, 10, 29, 0, 0), '215 Main St', 'Los Angeles', 'Region 3', '31023', 'France', '481-7468', '807', 'No notes', 2, 'photos/alice.jpg', 7836.22)]

# %%
# %%sql
# SELECT
#     *
# FROM
#     Customers ;
# Out:
#  * mysql+pymysql://root:***@localhost/Northwind
#    sqlite:///Northwind.db
# 2 rows affected.
# [(1, 'Cairo Market', 'Mona Ahmed', 'Manager', '12 Nile St', 'Cairo', 'Cairo', 'Egypt', '0123456789', '0123456780'),
#  (2, 'Alex Foods', 'Ali Hassan', 'Owner', '5 Sea Rd', 'Alexandria', 'Alex', 'Egypt', '0109876543', '0109876500')]

# %%
# %%sql
# SELECT
#     unit_price ,
#     discontinued
# FROM
#     products
# WHERE
#     unit_price > 30
#     AND  discontinued = 1 ;
# Out:
#  * mysql+pymysql://root:***@localhost/Northwind
#    sqlite:///Northwind.db
# 5 rows affected.
# [(Decimal('40.00'), b'\x01'),
#  (Decimal('97.00'), b'\x01'),
#  (Decimal('39.00'), b'\x01'),
#  (Decimal('31.23'), b'\x01'),
#  (Decimal('123.79'), b'\x01')]

# %%
# %%sql
# SELECT
#     contact_name ,
#     phone ,
#     country
# FROM
#     customers
# WHERE
#     country = 'USA'
#     OR country = 'Canada';
# Out:
#  * mysql+pymysql://root:***@localhost/Northwind
#    sqlite:///Northwind.db
# 50 rows affected.
# [('Alice Smith', '555-1001', 'USA'),
#  ('Bob Johnson', '555-1002', 'USA'),
#  ('Carol Lee', '555-1003', 'USA'),
#  ('David Kim', '555-1004', 'USA'),
#  ('Eve Davis', '555-1005', 'USA'),
#  ('Zack White', '555-1006', 'USA'),
#  ('Ella Brown', '555-1007', 'USA'),
#  ('Tom Black', '555-1008', 'USA'),
#  ('Ivy Green', '555-1009', 'USA'),
#  ('Ken Blue', '555-1010', 'USA'),
#  ('Liam Smith', '555-1011', 'USA'),
#  ('Mia Lee', '555-1012', 'USA'),
#  ('Noah Kim', '555-1013', 'USA'),
#  ('Xena Davis', '555-1014', 'USA'),
#  ('Oscar White', '555-1015', 'USA'),
#  ('Paul Brown', '555-1016', 'USA'),
#  ('Rachel Black', '555-1017', 'USA'),
#  ('Sam Green', '555-1018', 'USA'),
#  ('Tina Blue', '555-1019', 'USA'),
#  ('Uma Smith', '555-1020', 'USA'),
#  ('Phil Smith', '555-1021', 'USA'),
#  ('Chloe Lee', '555-1022', 'USA'),
#  ('Peter Kim', '555-1023', 'USA'),
#  ('Olga Davis', '555-1024', 'USA'),
# ...

# %%
# %%sql
# SELECT
#     first_name,
#     last_name,
#     city ,
#     title
# FROM
#     employee
# WHERE
#     (title = 'Accountant '
#     OR title =  'Manager'
#     )
#     AND city = 'Pierre '
#     OR city = 'Pittsburgh';
# Out:
#  * mysql+pymysql://root:***@localhost/Northwind
#    sqlite:///Northwind.db
# 1 rows affected.
# [('Chris', 'Cooper', 'Pittsburgh', 'Manager')]
